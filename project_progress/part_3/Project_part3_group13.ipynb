# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 65.2 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import re
import csv
import json
import math
import time
import string
import collections
import numpy as np
from numpy import linalg as la
from collections import defaultdict
from array import array
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.stem import PorterStemmer, WordNetLemmatizer
import pandas as pd
import matplotlib.pyplot as plt
from gensim.downloader import load
from gensim.utils import simple_preprocess
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
from wordcloud import WordCloud
import seaborn as sns

nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')
nltk.download('punkt', quiet=True)
nltk.download('averaged_perceptron_tagger', quiet=True)
nltk.download('maxent_ne_chunker', quiet=True)
nltk.download('words', quiet=True)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Paths of the documents used in this notebook.
# Change as necessary
docs_path = '/content/drive/MyDrive/fashion_products_dataset.json'
validation_path = '/content/drive/MyDrive/validation_labels.csv'
our_validation_path = '/content/drive/MyDrive/our_queries_validation.csv'


with open(docs_path, 'r') as fp:
    lines = json.load(fp)

# %%
queries = {
    1: "men cotton blend grey t shirt",
    2: "light blue jeans for men slim fit",
    3: "women casual wear cotton shirt",
    4: "printed navy top for women",
    5: "regular fit denim jeans"
}

# %%
def build_terms(line):
    """
    Preprocess the text (title + description):
    - Lowercase
    - Remove punctuation and special symbols (e.g., ₹, %, ™)
    - Normalize spaces
    - Tokenization
    - Remove stop words
    - Lemmatization
    - Stemming
    """
    stemmer = PorterStemmer()
    lemmatizer = WordNetLemmatizer()
    stop_words = set(stopwords.words("english"))

    # Lowercase
    line = line.lower()

    # Remove punctuation and uncommon symbols
    line = re.sub(r"[^\w\s]", " ", line)

    # Normalize spaces
    line = re.sub(r"\s+", " ", line).strip()

    # Tokenize
    tokens = line.split()

    # Remove stop words
    tokens = [w for w in tokens if w not in stop_words]

    # Lemmatization (reduces words to their base form)
    tokens = [lemmatizer.lemmatize(w) for w in tokens]

    # Stemming (we don't need, explained in the report)
    tokens = [stemmer.stem(w) for w in tokens]

    return tokens

# %%
def create_index_with_tfidf(lines):
    # Initialize data structures
    index = defaultdict(list)
    products_info = {}
    tf = defaultdict(dict)
    df = defaultdict(int)
    idf = defaultdict(float)

    num_documents = len(lines)

    for doc in lines:
        pid = doc.get("pid", "")
        title = doc.get("title", "")
        description = doc.get("description", "")
        brand = doc.get("brand", "")
        category = doc.get("category", "")
        sub_category = doc.get("sub_category", "")
        product_details = doc.get("product_details", "")
        seller = doc.get("seller", "")
        out_of_stock = doc.get("out_of_stock", "")
        selling_price_str = doc.get("selling_price", "").replace(',', '')
        selling_price = float(selling_price_str) if selling_price_str else 0.0
        discount_str = doc.get("discount", "").strip('% off')
        discount = float(discount_str) if discount_str else 0.0
        actual_price_str = doc.get("actual_price", "").replace(',', '')
        actual_price = float(actual_price_str) if actual_price_str else 0.0
        average_rating_str = doc.get("average_rating", "")
        average_rating = float(average_rating_str) if average_rating_str else None
        url = doc.get("url", "")

        text = f"{title} {description}"
        terms = build_terms(text)

        products_info[pid] = {
            "pid": pid,
            "title": title,
            "description": description,
            "brand": brand,
            "category": category,
            "sub_category": sub_category,
            "product_details": product_details,
            "seller": seller,
            "out_of_stock": out_of_stock,
            "selling_price": selling_price,
            "discount": discount,
            "actual_price": actual_price,
            "average_rating": average_rating,
            "url": url
        }

        # Compute term frequency and positional index for the current document
        term_freq = defaultdict(int)
        current_page_index = {}

        for position, term in enumerate(terms):
            term_freq[term] += 1
            try:
                current_page_index[term][1].append(position)
            except:
                current_page_index[term] = [pid, array('I', [position])]

        # Update inverted index and document frequency for each term
        for term, posting in current_page_index.items():
            df[term] += 1
            index[term].append(posting)

        # Compute TF for each term in the doc
        for term, freq in term_freq.items():
            if freq > 0:
                tfidf_weight = (1 + math.log(freq))  # IDF will be applied later
                tf[term][pid] = round(tfidf_weight, 4)
            else:
                tf[term][pid] = 0.0

    # Compute IDF for each term
    for term in df:
        idf[term] = round(math.log(num_documents / df[term]), 4)

    return index, products_info, tf, df, idf

# %%
start_time = time.time()
index, products_info, tf, df, idf = create_index_with_tfidf(lines)
print("Total time to create the index: {} seconds".format(np.round(time.time() - start_time, 2)))
# Out:
# Total time to create the index: 53.96 seconds

# %% [markdown]
# # **PART 1**

# %% [markdown]
# # 1. RANKING WITH TF-IDF

# %%
def rank_products_tf_idf(query_terms, docs, index, idf, tf, products_info):
    # Initialize document vectors and query vector
    doc_vectors = defaultdict(lambda: [0] * len(query_terms))
    query_vector = [0] * len(query_terms)

    # Count term frequencies in the query
    query_terms_count = collections.Counter(query_terms)
    query_norm = la.norm(list(query_terms_count.values()))

    # Build the weighted query vector using TF-IDF
    for termIndex, term in enumerate(query_terms):
        if term not in index:
            continue
        query_vector[termIndex] = query_terms_count[term] / query_norm * idf[term]

        # Assign TF-IDF weights to documents containing the term
        for (pid, _) in index[term]:
            if pid in docs and pid in tf[term]:
                doc_vectors[pid][termIndex] = tf[term][pid] * idf[term]

    # Compute cosine similarity between query and each document
    doc_scores = []
    for pid, doc_vec in doc_vectors.items():
        doc_norm = la.norm(doc_vec)
        if doc_norm == 0:
            score = 0.0
        else:
            score = np.dot(doc_vec, query_vector) / doc_norm
        doc_scores.append([score, pid])

    # Sort documents by descending similarity score
    doc_scores.sort(reverse=True)
    result_docs = [x[1] for x in doc_scores]

    return result_docs, doc_scores

# %% [markdown]
# # 2. RANKING WITH BM25

# %%
def rank_products_bm25(query_terms, index, idf, tf, products_info, docs=None, k1=1.5, b=0.75):
    doc_scores = defaultdict(float)
    doc_lengths = {}
    total_length = 0

    if docs is None:
        docs = products_info.keys()

    # Compute document lengths
    for pid in docs:
        text = f"{products_info[pid]['title']} {products_info[pid]['description']}"
        doc_length = len(build_terms(text))
        doc_lengths[pid] = doc_length
        total_length += doc_length

    num_docs = len(docs)
    avg_doc_length = total_length / num_docs if num_docs > 0 else 0

    # Compute BM25 score for each document
    for term in query_terms:
        if term not in index:
            continue
        for pid, _ in index[term]:
            if pid not in docs:
                continue
            if pid in tf[term]:
                f = tf[term][pid]
                idf_term = idf[term]
                numerator = f * (k1 + 1)
                denominator = f + k1 * (1 - b + b * (doc_lengths[pid] / avg_doc_length))
                score = idf_term * (numerator / denominator)
                doc_scores[pid] += score

    # Sort documents by score
    ranked_docs = sorted(doc_scores.items(), key=lambda x: x[1], reverse=True)
    result_docs = [pid for pid, score in ranked_docs]

    return result_docs, ranked_docs

# %% [markdown]
# # 3. SIMPLE CUSTOMIZED RANKING

# %%
def rank_products_custom1(query_terms, index, idf, tf, products_info, docs=None, k1=1.5, b=0.75, alpha=0.7, beta=0.2, gamma=0.1):
    """
    Custom ranking that combines BM25 text relevance with product attributes
    like rating and discount.
    """
    if docs is None:
        docs = products_info.keys()

    # Compute basic BM25
    bm25_docs, bm25_scores = rank_products_bm25(query_terms, index, idf, tf, products_info, docs=list(docs), k1=k1, b=b)

    # Convert into dictionary
    bm25_dict = dict(bm25_scores)

    # Normalize rating and discount
    scores = {}
    for pid in docs:
        info = products_info[pid]
        bm25_val = bm25_dict.get(pid, 0)

        rating = info.get("average_rating", 0) or 0
        discount = info.get("discount", 0) or 0

        normalized_rating = rating / 5.0
        normalized_discount = discount / 100.0

        # Combine with weights
        custom = alpha * bm25_val + beta * normalized_rating + gamma * normalized_discount
        scores[pid] = custom

    ranked_docs = sorted(scores.items(), key=lambda x: x[1], reverse=True)
    result_docs = [pid for pid, _ in ranked_docs]

    return result_docs, ranked_docs

# %% [markdown]
# # 4. ADVANCED CUSTOMIZED RANKING

# %%
def rank_products_custom2(query_terms, index, idf, tf, products_info, docs):
    doc_scores = defaultdict(float)

    for pid in docs:
        info = products_info[pid]

        title_text = info["title"].lower()
        description_text = info["description"].lower()

        #base textual score (TF-IDF)
        base_score = 0.0

        for term in query_terms:
            if term in tf and pid in tf[term]:
                tfidf_score = tf[term][pid] * idf.get(term, 0.0)

                #Title weighting applied
                if term in title_text:
                    tfidf_score *= 2.0

                base_score += tfidf_score

        #rating + review
        rating = float(info.get("average_rating", 0) or 0.0)
        rating_norm = rating / 5.0

        review_count = float(info.get("rating_count", 1.0) or 1.0)
        review_boost = math.log1p(review_count) / 3.0

        social_proof = 1 + (0.4 * rating_norm) * (0.3 + review_boost)

        #price and discount
        price = float(info.get("selling_price", 1.0) or 1.0)
        if price <= 0:
            price = 1.0

        price_penalty = 1 / (1 + math.log1p(price))

        discount = float(info.get("discount", 0.0) or 0.0) / 100.0
        discount_boost = 1 + 0.2 * discount


        #if no stock we don't want the product
        stock_boost = 0 if info.get("out_of_stock", False) else 1.0

        #final score
        final_score = (base_score * social_proof * discount_boost * price_penalty * stock_boost)

        doc_scores[pid] = final_score

    ranked_docs = sorted(doc_scores.items(), key=lambda x: x[1], reverse=True)
    result_docs = [pid for pid, _ in ranked_docs]

    return result_docs, ranked_docs

# %% [markdown]
# # SEARCH

# %%
def search_products(query, index, idf, tf, products_info, ranking_method):
    query_terms = build_terms(query)
    if not query_terms:
        return [], []

    first_term = query_terms[0]
    if first_term not in index:
        return [], []
    docs = set(posting[0] for posting in index[first_term])

    for term in query_terms[1:]:
        if term not in index:
            return [], []
        term_docs = set(posting[0] for posting in index[term])
        docs &= term_docs
        if not docs:
            return [], []

    if ranking_method.lower() == "bm25":
        ranked_docs, doc_scores = rank_products_bm25(query_terms, index, idf, tf, products_info, docs=list(docs))
    elif ranking_method.lower() == "custom1":
        ranked_docs, doc_scores = rank_products_custom1(query_terms, index, idf, tf, products_info, docs=list(docs))
    elif ranking_method.lower() == "custom2":
        ranked_docs, doc_scores = rank_products_custom2(query_terms, index, idf, tf, products_info, docs=list(docs))
    else:
        ranked_docs, doc_scores = rank_products_tf_idf(query_terms, list(docs), index, idf, tf, products_info)

    return ranked_docs, doc_scores

# %% [markdown]
# # IMPLEMENTATION

# %%
queries = {
    1: "men cotton blend grey t shirt",
    2: "light blue jeans for men slim fit",
    3: "women casual wear cotton shirt",
    4: "printed navy top for women",
    5: "regular fit denim jeans"
}
methods = ["tf-idf", "bm25", "custom1", "custom2"]

for qid, query in queries.items():
  print(f"\n---- QUERY {query} ----")
  for method in methods:
    ranked_docs, scores = search_products(query, index, idf, tf, products_info, ranking_method=method)
    print(f"\nTop 20 ({method.upper()}) results for: '{query}'")
    if method == 'custom1':
      for pid, score in scores[:20]:
          info = products_info[pid]
          print(f" - {pid}: {info['title']} → score = {round(score, 4)} | rating={info['average_rating']} | discount={info['discount']}")
    elif method == 'bm25':
      for pid, score in scores[:20]:
          info = products_info[pid]
          print(f" - {pid}: {info['title']} → score = {round(score, 4)}")
    elif method == 'custom2':
      for pid, score in scores[:20]:
          info = products_info[pid]
          print(f" - {pid}: {info['title']} → score = {round(score, 4)} | rating={info['average_rating']} | price={info['selling_price']}| discount={info['discount']}")
    else:
      for score, pid in scores[:20]:
        info = products_info[pid]
        print(f" - {pid}: {info['title']} → score = {round(score, 4)}")
# Out:
# ---- QUERY men cotton blend grey t shirt ----
#
# Top 20 (TF-IDF) results for: 'men cotton blend grey t shirt'
#  - TKPFYGUNNFVNFQF7: Solid Men Grey Track Pants → score = 1.8456
#  - TSHEXZ8KYFDUHVYY: Solid Men Round Neck Multicolor T-Shirt  (Pack of 2) → score = 1.8387
#  - TSHEXZ8KHNVHEEK6: Solid Men V-neck Multicolor T-Shirt  (Pack of 2) → score = 1.8387
#  - TSHEXZ8KBEKYQYTZ: Solid Men V-Neck Multicolor T-Shirt  (Pack of 2) → score = 1.8387
#  - TSHER6FBWFYYR5GG: Solid Men Round Neck Multicolor T-Shirt  (Pack of 3) → score = 1.8387
#  - TSHER6F4RWS54H9F: Solid Men Round Neck Multicolor T-Shirt  (Pack of 2) → score = 1.8387
#  - TSHENYJ28ZCH4H4V: Solid Men Round Neck Multicolor T-Shirt  (Pack of 5) → score = 1.8387
#  - TSHENYGRN9XHQUVF: Solid Men Round Neck Multicolor T-Shirt  (Pack of 3) → score = 1.8387
#  - TSHENXFZHDWREHFT: Solid Men V-neck Multicolor T-Shirt  (Pack of 3) → score = 1.8387
#  - TSHENXFW8CZCTVU5: Solid Men V-neck Multicolor T-Shirt  (Pack of 3) → score = 1.8387
#  - TSHFZ3JDVAYZKCFC: Solid Men Round Neck Grey T-Shirt → score = 1.8318
#  - TSHFZ3JDHZSGCFHT: Solid Men Round Neck Grey T-Shirt → score = 1.8318
#  - TROEATNWHJJFVQ6Y: Regular Fit Men Grey Cotton Blend Trousers → score = 1.815
#  - TSHFUXPWUR2ZTEE2: Color Block Men V Neck Dark Blue T-Shirt → score = 1.8087
#  - TROFCCRXZRFBFXGA: Regular Fit Men Grey Cotton Blend Trousers → score = 1.8067
#  - TSHFWDBQCVDSQT7B: Solid Men Polo Neck Grey T-Shirt → score = 1.8033
#  - TROFCCRYVP6EVGQT: Regular Fit Men Grey Satin Blend Trousers → score = 1.7844
#  - TROFCCRY3FJAHHQB: Regular Fit Men Grey Satin Blend Trousers → score = 1.7844
#
# Top 20 (BM25) results for: 'men cotton blend grey t shirt'
#  - TROFCCRY3FJAHHQB: Regular Fit Men Grey Satin Blend Trousers → score = 11.4803
#  - TROFCCRYVP6EVGQT: Regular Fit Men Grey Satin Blend Trousers → score = 11.1442
#  - TSHFZ3JDHZSGCFHT: Solid Men Round Neck Grey T-Shirt → score = 11.0235
#  - TSHFZ3JDVAYZKCFC: Solid Men Round Neck Grey T-Shirt → score = 11.0235
#  - TSHEXZ8KHNVHEEK6: Solid Men V-neck Multicolor T-Shirt  (Pack of 2) → score = 10.9489
#  - TSHEXZ8KYFDUHVYY: Solid Men Round Neck Multicolor T-Shirt  (Pack of 2) → score = 10.9489
#  - TSHEXZ8KBEKYQYTZ: Solid Men V-Neck Multicolor T-Shirt  (Pack of 2) → score = 10.9489
#  - TSHENXFZHDWREHFT: Solid Men V-neck Multicolor T-Shirt  (Pack of 3) → score = 10.8538
#  - TSHER6FBWFYYR5GG: Solid Men Round Neck Multicolor T-Shirt  (Pack of 3) → score = 10.8538
#  - TSHER6F4RWS54H9F: Solid Men Round Neck Multicolor T-Shirt  (Pack of 2) → score = 10.8538
#  - TSHENYGRN9XHQUVF: Solid Men Round Neck Multicolor T-Shirt  (Pack of 3) → score = 10.7603
#  - TSHENXFW8CZCTVU5: Solid Men V-neck Multicolor T-Shirt  (Pack of 3) → score = 10.7603
#  - TROEATNWHJJFVQ6Y: Regular Fit Men Grey Cotton Blend Trousers → score = 10.7098
#  - TSHENYJ28ZCH4H4V: Solid Men Round Neck Multicolor T-Shirt  (Pack of 5) → score = 10.6684
#  - TROFCCRXZRFBFXGA: Regular Fit Men Grey Cotton Blend Trousers → score = 10.5353
#  - TSHFWDBQCVDSQT7B: Solid Men Polo Neck Grey T-Shirt → score = 7.8967
#  - TKPFYGUNNFVNFQF7: Solid Men Grey Track Pants → score = 6.382
#  - TSHFUXPWUR2ZTEE2: Color Block Men V Neck Dark Blue T-Shirt → score = 4.3718
#
# Top 20 (CUSTOM1) results for: 'men cotton blend grey t shirt'
#  - TROFCCRY3FJAHHQB: Regular Fit Men Grey Satin Blend Trousers → score = 8.2352 | rating=4.3 | discount=27.0
#  - TROFCCRYVP6EVGQT: Regular Fit Men Grey Satin Blend Trousers → score = 8.0279 | rating=5.0 | discount=27.0
#  - TSHFZ3JDHZSGCFHT: Solid Men Round Neck Grey T-Shirt → score = 7.9264 | rating=3.8 | discount=58.0
#  - TSHFZ3JDVAYZKCFC: Solid Men Round Neck Grey T-Shirt → score = 7.9244 | rating=4.0 | discount=48.0
#  - TSHEXZ8KBEKYQYTZ: Solid Men V-Neck Multicolor T-Shirt  (Pack of 2) → score = 7.8492 | rating=4.0 | discount=25.0
#  - TSHEXZ8KHNVHEEK6: Solid Men V-neck Multicolor T-Shirt  (Pack of 2) → score = 7.8412 | rating=3.8 | discount=25.0
#  - TSHEXZ8KYFDUHVYY: Solid Men Round Neck Multicolor T-Shirt  (Pack of 2) → score = 7.8412 | rating=3.8 | discount=25.0
#  - TSHER6FBWFYYR5GG: Solid Men Round Neck Multicolor T-Shirt  (Pack of 3) → score = 7.7836 | rating=4.0 | discount=26.0
#  - TSHER6F4RWS54H9F: Solid Men Round Neck Multicolor T-Shirt  (Pack of 2) → score = 7.7746 | rating=3.6 | discount=33.0
#  - TSHENXFZHDWREHFT: Solid Men V-neck Multicolor T-Shirt  (Pack of 3) → score = 7.7716 | rating=3.8 | discount=22.0
#  - TSHENYGRN9XHQUVF: Solid Men Round Neck Multicolor T-Shirt  (Pack of 3) → score = 7.7292 | rating=4.1 | discount=33.0
#  - TSHENXFW8CZCTVU5: Solid Men V-neck Multicolor T-Shirt  (Pack of 3) → score = 7.6892 | rating=3.1 | discount=33.0
#  - TROEATNWHJJFVQ6Y: Regular Fit Men Grey Cotton Blend Trousers → score = 7.6719 | rating=3.9 | discount=19.0
#  - TSHENYJ28ZCH4H4V: Solid Men Round Neck Multicolor T-Shirt  (Pack of 5) → score = 7.6529 | rating=3.8 | discount=33.0
#  - TROFCCRXZRFBFXGA: Regular Fit Men Grey Cotton Blend Trousers → score = 7.5617 | rating=4.0 | discount=27.0
#  - TSHFWDBQCVDSQT7B: Solid Men Polo Neck Grey T-Shirt → score = 5.6837 | rating=3.9 | discount=0.0
#  - TKPFYGUNNFVNFQF7: Solid Men Grey Track Pants → score = 4.6804 | rating=3.8 | discount=61.0
#  - TSHFUXPWUR2ZTEE2: Color Block Men V Neck Dark Blue T-Shirt → score = 3.1963 | rating=2.0 | discount=56.0
#
# Top 20 (CUSTOM2) results for: 'men cotton blend grey t shirt'
#  - TSHFUXPWUR2ZTEE2: Color Block Men V Neck Dark Blue T-Shirt → score = 5.0323 | rating=2.0 | price=349.0| discount=56.0
#  - TROFCCRYVP6EVGQT: Regular Fit Men Grey Satin Blend Trousers → score = 3.0063 | rating=5.0 | price=1074.0| discount=27.0
#  - TROFCCRY3FJAHHQB: Regular Fit Men Grey Satin Blend Trousers → score = 2.9326 | rating=4.3 | price=1074.0| discount=27.0
#  - TROFCCRXZRFBFXGA: Regular Fit Men Grey Cotton Blend Trousers → score = 2.7905 | rating=4.0 | price=1074.0| discount=27.0
#  - TSHFZ3JDHZSGCFHT: Solid Men Round Neck Grey T-Shirt → score = 2.2458 | rating=3.8 | price=618.0| discount=58.0
#  - TSHFZ3JDVAYZKCFC: Solid Men Round Neck Grey T-Shirt → score = 2.1561 | rating=4.0 | price=775.0| discount=48.0
#  - TSHFWDBQCVDSQT7B: Solid Men Polo Neck Grey T-Shirt → score = 2.1314 | rating=3.9 | price=699.0| discount=0.0
#  - TKPFYGUNNFVNFQF7: Solid Men Grey Track Pants → score = 2.0395 | rating=3.8 | price=499.0| discount=61.0
#  - TSHEXZ8KBEKYQYTZ: Solid Men V-Neck Multicolor T-Shirt  (Pack of 2) → score = 1.7172 | rating=4.0 | price=446.0| discount=25.0
#  - TSHEXZ8KHNVHEEK6: Solid Men V-neck Multicolor T-Shirt  (Pack of 2) → score = 1.7032 | rating=3.8 | price=449.0| discount=25.0
#  - TSHEXZ8KYFDUHVYY: Solid Men Round Neck Multicolor T-Shirt  (Pack of 2) → score = 1.7032 | rating=3.8 | price=449.0| discount=25.0
#  - TSHENYGRN9XHQUVF: Solid Men Round Neck Multicolor T-Shirt  (Pack of 3) → score = 1.682 | rating=4.1 | price=594.0| discount=33.0
#  - TSHER6F4RWS54H9F: Solid Men Round Neck Multicolor T-Shirt  (Pack of 2) → score = 1.6497 | rating=3.6 | price=599.0| discount=33.0
#  - TSHENXFW8CZCTVU5: Solid Men V-neck Multicolor T-Shirt  (Pack of 3) → score = 1.6193 | rating=3.1 | price=599.0| discount=33.0
#  - TSHENXFZHDWREHFT: Solid Men V-neck Multicolor T-Shirt  (Pack of 3) → score = 1.5943 | rating=3.8 | price=699.0| discount=22.0
#  - TSHER6FBWFYYR5GG: Solid Men Round Neck Multicolor T-Shirt  (Pack of 3) → score = 1.5691 | rating=4.0 | price=886.0| discount=26.0
#  - TSHENYJ28ZCH4H4V: Solid Men Round Neck Multicolor T-Shirt  (Pack of 5) → score = 1.5545 | rating=3.8 | price=999.0| discount=33.0
#  - TROEATNWHJJFVQ6Y: Regular Fit Men Grey Cotton Blend Trousers → score = 0.0 | rating=3.9 | price=1281.0| discount=19.0
#
# ---- QUERY light blue jeans for men slim fit ----
#
# Top 20 (TF-IDF) results for: 'light blue jeans for men slim fit'
#  - JEAFPMKZGHS2ZTKG: Slim Men Light Blue Jeans → score = 2.0163
#  - JEAFRAQVRVMEUZUZ: Slim Men Blue Jeans → score = 1.9884
#  - JEAFUZXT2J3VV2RR: Tapered Fit Men Light Blue Jeans → score = 1.9761
#  - JEAFUZXSHCZNHQE4: Tapered Fit Men Light Blue Jeans → score = 1.9761
#  - JEAFSKYHHDQ2SDZQ: Tapered Fit Men Light Blue Jeans → score = 1.9761
#  - TSHE6WQC3WHWXNPZ: Solid Men Polo Neck Dark Blue T-Shirt → score = 1.967
#  - JEAEHGRJSGGYEYYX: Slim Men Light Blue Jeans → score = 1.9497
#  - JEAFRARNKDFYXUYW: Slim Men Blue Jeans → score = 1.925
#  - JEAFRAQYJAGJSJUY: Slim Men Blue Jeans → score = 1.925
#  - JEAFEC2GEMGBWHA5: Slim Men Light Blue Jeans → score = 1.8398
#
# Top 20 (BM25) results for: 'light blue jeans for men slim fit'
#  - JEAFUZXSHCZNHQE4: Tapered Fit Men Light Blue Jeans → score = 17.4557
#  - JEAFSKYHHDQ2SDZQ: Tapered Fit Men Light Blue Jeans → score = 17.2126
#  - JEAFUZXT2J3VV2RR: Tapered Fit Men Light Blue Jeans → score = 17.2126
#  - JEAEHGRJSGGYEYYX: Slim Men Light Blue Jeans → score = 16.8508
#  - JEAFPMKZGHS2ZTKG: Slim Men Light Blue Jeans → score = 15.471
#  - JEAFRAQVRVMEUZUZ: Slim Men Blue Jeans → score = 14.0423
#  - JEAFRAQYJAGJSJUY: Slim Men Blue Jeans → score = 12.6911
#  - JEAFRARNKDFYXUYW: Slim Men Blue Jeans → score = 12.3208
#  - JEAFEC2GEMGBWHA5: Slim Men Light Blue Jeans → score = 9.8123
#  - TSHE6WQC3WHWXNPZ: Solid Men Polo Neck Dark Blue T-Shirt → score = 9.135
#
# Top 20 (CUSTOM1) results for: 'light blue jeans for men slim fit'
#  - JEAFUZXSHCZNHQE4: Tapered Fit Men Light Blue Jeans → score = 12.337 | rating=2.5 | discount=18.0
#  - JEAFSKYHHDQ2SDZQ: Tapered Fit Men Light Blue Jeans → score = 12.2468 | rating=4.7 | discount=10.0
#  - JEAFUZXT2J3VV2RR: Tapered Fit Men Light Blue Jeans → score = 12.1688 | rating=2.5 | discount=20.0
#  - JEAEHGRJSGGYEYYX: Slim Men Light Blue Jeans → score = 11.9456 | rating=3.0 | discount=30.0
#  - JEAFPMKZGHS2ZTKG: Slim Men Light Blue Jeans → score = 10.9827 | rating=3.0 | discount=33.0
#  - JEAFRAQVRVMEUZUZ: Slim Men Blue Jeans → score = 9.9636 | rating=2.2 | discount=46.0
#  - JEAFRAQYJAGJSJUY: Slim Men Blue Jeans → score = 8.9038 | rating=None | discount=20.0
#  - JEAFRARNKDFYXUYW: Slim Men Blue Jeans → score = 8.6645 | rating=None | discount=40.0
#  - JEAFEC2GEMGBWHA5: Slim Men Light Blue Jeans → score = 7.0826 | rating=3.9 | discount=58.0
#  - TSHE6WQC3WHWXNPZ: Solid Men Polo Neck Dark Blue T-Shirt → score = 6.6235 | rating=4.1 | discount=65.0
#
# Top 20 (CUSTOM2) results for: 'light blue jeans for men slim fit'
#  - JEAFEC2GEMGBWHA5: Slim Men Light Blue Jeans → score = 6.5863 | rating=3.9 | price=629.0| discount=58.0
#  - JEAFSKYHHDQ2SDZQ: Tapered Fit Men Light Blue Jeans → score = 4.5493 | rating=4.7 | price=1349.0| discount=10.0
#  - JEAEHGRJSGGYEYYX: Slim Men Light Blue Jeans → score = 4.5224 | rating=3.0 | price=699.0| discount=30.0
#  - JEAFRAQVRVMEUZUZ: Slim Men Blue Jeans → score = 4.3006 | rating=2.2 | price=2040.0| discount=46.0
#  - JEAFUZXT2J3VV2RR: Tapered Fit Men Light Blue Jeans → score = 4.2438 | rating=2.5 | price=1439.0| discount=20.0
#  - JEAFUZXSHCZNHQE4: Tapered Fit Men Light Blue Jeans → score = 4.201 | rating=2.5 | price=1516.0| discount=18.0
#  - TSHE6WQC3WHWXNPZ: Solid Men Polo Neck Dark Blue T-Shirt → score = 3.2379 | rating=4.1 | price=449.0| discount=65.0
#  - JEAFPMKZGHS2ZTKG: Slim Men Light Blue Jeans → score = 3.0121 | rating=3.0 | price=1799.0| discount=33.0
#  - JEAFRAQYJAGJSJUY: Slim Men Blue Jeans → score = 0.0 | rating=None | price=2719.0| discount=20.0
#  - JEAFRARNKDFYXUYW: Slim Men Blue Jeans → score = 0.0 | rating=None | price=2999.0| discount=40.0
#
# ---- QUERY women casual wear cotton shirt ----
#
# Top 20 (TF-IDF) results for: 'women casual wear cotton shirt'
#  - TSHFVYX6VQDQ3GT7: Typography Women Round Neck Red T-Shirt → score = 1.1759
#  - TSHFVY6KSVYNDBPG: Printed Women Round Neck Black T-Shirt → score = 1.1759
#  - TSHFVY6J8UYHQEZY: Printed Women Round Neck Maroon T-Shirt → score = 1.1759
#  - TSHFVY6GCCCJPFDE: Printed Women Round Neck Blue T-Shirt → score = 1.1759
#  - TSHFVY4TGTRZB6ZH: Printed Women Round Neck Black T-Shirt → score = 1.1759
#  - TSHFUYZ9KMUHAADH: Printed Women Round Neck Maroon T-Shirt → score = 1.1759
#  - TSHFUTGMXD3QVMGV: Printed Women Round Neck White T-Shirt → score = 1.1759
#  - TSHFUMHHUHMFQQHX: Printed Women Round Neck Grey T-Shirt → score = 1.1759
#  - TSHFUMHFZYCWD3WA: Printed Women Round Neck White T-Shirt → score = 1.1759
#  - TSHFUGH48CFJDMGD: Printed Women Round Neck Black T-Shirt → score = 1.1759
#  - TSHFUF8GGSCRYW9H: Printed Women V Neck Yellow T-Shirt → score = 1.1759
#  - TSHFUF5PXJMVGG4M: Printed Women Round Neck White T-Shirt → score = 1.1759
#  - TSHFUF4SN5UTAYEZ: Printed Women Round Neck Black T-Shirt → score = 1.1759
#  - TSHFUF4SDCVHAVJ3: Printed Women Round Neck Black T-Shirt → score = 1.1759
#  - TSHFUF3FC74KU3BK: Printed Women Round Neck Blue T-Shirt → score = 1.1759
#  - TSHFUF3FASGCQXKG: Printed Women Round Neck Red T-Shirt → score = 1.1759
#  - TSHFUF2ZJ3HGYBEV: Printed Women Round Neck Green T-Shirt → score = 1.1759
#  - TSHFUF2YBGGM69AH: Printed Women Round Neck Black T-Shirt → score = 1.1759
#  - TSHFUF2YA6PHBQKG: Printed Women Round Neck Blue T-Shirt → score = 1.1759
#  - TSHFUBZSBYWPZZZQ: Printed Women Round Neck Black T-Shirt → score = 1.1759
#
# Top 20 (BM25) results for: 'women casual wear cotton shirt'
#  - SHTFPGVCR3PN7ZME: Women Regular Fit Printed Casual Shirt → score = 8.2311
#  - TSHFHHSFHBJHVHEZ: Printed Women Round Neck Beige T-Shirt → score = 8.2184
#  - TSHFGK3FYD6Y5EDS: Checkered Women Round Neck Beige T-Shirt → score = 8.2184
#  - TSHFGK3FM5KYBJ7Q: Checkered Women Round Neck White T-Shirt → score = 8.2184
#  - TSHFHHSFFMJ4SBJE: Printed Women Round Neck Yellow T-Shirt → score = 8.2184
#  - TSHFGK3SHD2RRJMR: Checkered Women Round Neck Grey T-Shirt → score = 8.2184
#  - TSHFGK3SGWTFWTZP: Checkered Women Round Neck White T-Shirt → score = 8.2184
#  - TSHFGK3S4UZZMFC2: Checkered Women Round Neck Beige T-Shirt → score = 8.2184
#  - TSHFGK3YQT4YNQHB: Checkered Women Round Neck Grey T-Shirt → score = 8.2184
#  - TSHFHTGB7UY3UQYH: Solid Women Polo Neck Yellow T-Shirt → score = 8.0664
#  - TSHFHTGBACJZTSDT: Solid Women Polo Neck Yellow T-Shirt → score = 8.0664
#  - TSHFHTGBDQFXJGSR: Solid Women Polo Neck Yellow T-Shirt → score = 8.0664
#  - SHTEX5EAGX4PJWVR: Women Slim Fit Solid Spread Collar Casual Shirt → score = 7.9698
#  - TSHFHTGGPM7CZMZU: Color Block Women Polo Neck Blue T-Shirt → score = 7.9564
#  - TSHFHTGGYAZKDG6G: Color Block Women Polo Neck Blue T-Shirt → score = 7.9564
#  - TSHFHTGGUAHXZQEU: Color Block Women Polo Neck Blue T-Shirt → score = 7.9564
#  - TSHFHTGKHFUHK85E: Color Block Women Polo Neck Green T-Shirt → score = 7.9564
#  - TSHFHTGUH8NH7XFJ: Self Design Women Polo Neck Blue T-Shirt → score = 7.9564
#  - TSHFHTGKDZHGH9K9: Color Block Women Polo Neck Green T-Shirt → score = 7.9564
#  - TSHFHTGGNPH5GGFD: Self Design Women Polo Neck White T-Shirt → score = 7.9564
#
# Top 20 (CUSTOM1) results for: 'women casual wear cotton shirt'
#  - TSHFGK3SHD2RRJMR: Checkered Women Round Neck Grey T-Shirt → score = 5.9799 | rating=4.3 | discount=55.0
#  - TSHFGK3SGWTFWTZP: Checkered Women Round Neck White T-Shirt → score = 5.9799 | rating=4.3 | discount=55.0
#  - TSHFGK3S4UZZMFC2: Checkered Women Round Neck Beige T-Shirt → score = 5.9799 | rating=4.3 | discount=55.0
#  - TSHFGK3FM5KYBJ7Q: Checkered Women Round Neck White T-Shirt → score = 5.9629 | rating=3.7 | discount=62.0
#  - TSHFGK3YQT4YNQHB: Checkered Women Round Neck Grey T-Shirt → score = 5.9629 | rating=3.7 | discount=62.0
#  - TSHFGK3FYD6Y5EDS: Checkered Women Round Neck Beige T-Shirt → score = 5.9629 | rating=3.7 | discount=62.0
#  - TSHFHHSFHBJHVHEZ: Printed Women Round Neck Beige T-Shirt → score = 5.9319 | rating=3.1 | discount=55.0
#  - TSHFHHSFFMJ4SBJE: Printed Women Round Neck Yellow T-Shirt → score = 5.9319 | rating=3.1 | discount=55.0
#  - SHTFPGVCR3PN7ZME: Women Regular Fit Printed Casual Shirt → score = 5.9047 | rating=2.2 | discount=55.0
#  - TSHFHTGB7UY3UQYH: Solid Women Polo Neck Yellow T-Shirt → score = 5.8455 | rating=3.3 | discount=67.0
#  - TSHFHTGBDQFXJGSR: Solid Women Polo Neck Yellow T-Shirt → score = 5.8455 | rating=3.3 | discount=67.0
#  - TSHFHTGBACJZTSDT: Solid Women Polo Neck Yellow T-Shirt → score = 5.8455 | rating=3.3 | discount=67.0
#  - TSHFHTGUH8NH7XFJ: Self Design Women Polo Neck Blue T-Shirt → score = 5.7885 | rating=3.8 | discount=67.0
#  - SHTEX5EAGX4PJWVR: Women Slim Fit Solid Spread Collar Casual Shirt → score = 5.7829 | rating=3.6 | discount=60.0
#  - TSHFHTGKDZHGH9K9: Color Block Women Polo Neck Green T-Shirt → score = 5.7685 | rating=3.3 | discount=67.0
#  - TSHFHTGGUAHXZQEU: Color Block Women Polo Neck Blue T-Shirt → score = 5.7685 | rating=3.3 | discount=67.0
#  - TSHFHTGGNPH5GGFD: Self Design Women Polo Neck White T-Shirt → score = 5.7685 | rating=3.3 | discount=67.0
#  - TSHFHTGKHFUHK85E: Color Block Women Polo Neck Green T-Shirt → score = 5.7685 | rating=3.3 | discount=67.0
#  - TSHFHTGGPM7CZMZU: Color Block Women Polo Neck Blue T-Shirt → score = 5.7685 | rating=3.3 | discount=67.0
#  - TSHFHTGGYAZKDG6G: Color Block Women Polo Neck Blue T-Shirt → score = 5.7685 | rating=3.3 | discount=67.0
#
# Top 20 (CUSTOM2) results for: 'women casual wear cotton shirt'
#  - SHTFUDVGKCMEQGGT: Women Regular Fit Checkered Tie up Collar Casual Shirt → score = 2.8095 | rating=4.0 | price=599.0| discount=70.0
#  - SHTFUTGPPQ6EHWRC: Women Regular Fit Solid Cut Away Collar Casual Shirt → score = 2.7254 | rating=3.0 | price=578.0| discount=71.0
#  - SHTFUTDMNP2BRUWW: Women Regular Fit Floral Print Tie up Collar Casual Shirt → score = 2.7075 | rating=3.0 | price=599.0| discount=70.0
#  - SHTFUES5Z6CWZF57: Women Regular Fit Printed Spread Collar Casual Shirt → score = 2.7075 | rating=3.0 | price=599.0| discount=70.0
#  - SHTFUTDMVGAVJ5QN: Women Regular Fit Solid Tie up Collar Casual Shirt → score = 2.7075 | rating=3.0 | price=599.0| discount=70.0
#  - SHTFUJCY6UYKCZPW: Women Regular Fit Self Design Spread Collar Casual Shirt → score = 2.7075 | rating=3.0 | price=599.0| discount=70.0
#  - SHTFUJBXTESZF4F9: Women Regular Fit Printed Slim Collar Casual Shirt → score = 2.7075 | rating=3.0 | price=599.0| discount=70.0
#  - SHTFUTCWVAQU3JWH: Women Regular Fit Floral Print Spread Collar Casual Shirt → score = 2.7075 | rating=3.0 | price=599.0| discount=70.0
#  - SHTFUTCYK3YGZHGC: Women Regular Fit Floral Print Spread Collar Casual Shirt → score = 2.7075 | rating=3.0 | price=599.0| discount=70.0
#  - SHTFW6YHRGU69RGY: Women Regular Fit Solid Spread Collar Casual Shirt → score = 2.592 | rating=2.4 | price=629.0| discount=62.0
#  - SHTFUTDMUBZQGUHP: Women Regular Fit Embroidered Tie up Collar Casual Shirt → score = 2.5604 | rating=3.0 | price=799.0| discount=60.0
#  - SHTFUTGF3AFWGKYX: Women Regular Fit Printed Tie up Collar Casual Shirt → score = 2.5604 | rating=3.0 | price=799.0| discount=60.0
#  - SHTFVVEHZUETFQAM: Women Tailored Fit Solid Casual Shirt → score = 2.5289 | rating=4.3 | price=359.0| discount=77.0
#  - SHTFXGZMBYHNGBDB: Women Slim Fit Solid Spread Collar Casual Shirt → score = 2.4961 | rating=4.0 | price=499.0| discount=54.0
#  - SHTFVVEHWHRGQMKY: Women Tailored Fit Solid Casual Shirt → score = 2.4821 | rating=4.3 | price=399.0| discount=75.0
#  - SHTFVVEHGDUN99HD: Women Tailored Fit Solid Casual Shirt → score = 2.4735 | rating=4.3 | price=399.0| discount=73.0
#  - SHTFVVEHGJJTM4QN: Women Tailored Fit Solid Casual Shirt → score = 2.4735 | rating=4.3 | price=399.0| discount=73.0
#  - TSHFX8CRNHK5KDZQ: Graphic Print Women Round Neck White T-Shirt → score = 2.2868 | rating=4.1 | price=299.0| discount=57.0
#  - TSHFN3V5FXM2GGBS: Printed Women Round Neck Yellow T-Shirt → score = 2.2802 | rating=4.2 | price=299.0| discount=50.0
#  - TSHFVR8F5BGXEZMK: Solid Women Collared Neck Grey T-Shirt → score = 2.2703 | rating=3.9 | price=299.0| discount=57.0
#
# ---- QUERY printed navy top for women ----
#
# Top 20 (TF-IDF) results for: 'printed navy top for women'
#  - TSHFGG5SHU3GER2F: Color Block Women Round Neck White, Blue T-Shirt → score = 2.8487
#  - TSHFGG5UDNX5GWSM: Printed Women Round Neck White, Blue T-Shirt → score = 2.8177
#  - SWSFZKX76KNARJ49: Full Sleeve Printed Women Sweatshirt → score = 2.803
#
# Top 20 (BM25) results for: 'printed navy top for women'
#  - SWSFZKX76KNARJ49: Full Sleeve Printed Women Sweatshirt → score = 15.2856
#  - TSHFGG5UDNX5GWSM: Printed Women Round Neck White, Blue T-Shirt → score = 9.2661
#  - TSHFGG5SHU3GER2F: Color Block Women Round Neck White, Blue T-Shirt → score = 9.0811
#
# Top 20 (CUSTOM1) results for: 'printed navy top for women'
#  - SWSFZKX76KNARJ49: Full Sleeve Printed Women Sweatshirt → score = 10.9499 | rating=5.0 | discount=50.0
#  - TSHFGG5UDNX5GWSM: Printed Women Round Neck White, Blue T-Shirt → score = 6.6973 | rating=3.6 | discount=67.0
#  - TSHFGG5SHU3GER2F: Color Block Women Round Neck White, Blue T-Shirt → score = 6.5968 | rating=4.3 | discount=68.0
#
# Top 20 (CUSTOM2) results for: 'printed navy top for women'
#  - TSHFGG5UDNX5GWSM: Printed Women Round Neck White, Blue T-Shirt → score = 2.652 | rating=3.6 | price=329.0| discount=67.0
#  - TSHFGG5SHU3GER2F: Color Block Women Round Neck White, Blue T-Shirt → score = 2.1559 | rating=4.3 | price=349.0| discount=68.0
#  - SWSFZKX76KNARJ49: Full Sleeve Printed Women Sweatshirt → score = 0.0 | rating=5.0 | price=1373.0| discount=50.0
#
# ---- QUERY regular fit denim jeans ----
#
# Top 20 (TF-IDF) results for: 'regular fit denim jeans'
#  - JEAEKNV83HZRKETB: Regular Men Blue Jeans → score = 2.3549
#  - JEAE8EWUZJDHNF4D: Sprint Denim Regular Men Dark Blue, Light Blue Jeans  (Pack of 2) → score = 2.2963
#  - JEAE6GBVY8SQQSUK: Sprin Regular Men Blue Jeans → score = 2.2839
#  - JEAE6GBVWBWFBHMJ: Sprin Regular Women Dark Blue Jeans → score = 2.2839
#  - JEAEKMF2V5RGFUBU: Regular Men Grey Jeans → score = 2.2804
#  - JEAE92Z37UYPWPVB: Regular Men Blue Jeans → score = 2.2795
#  - JEAEEVEQUPC3MHYK: Regular Women Black Jeans → score = 2.2765
#  - JEAEAFZKT8GHSGNA: Regular Women Dark Blue Jeans → score = 2.2765
#  - JEAEAFZKGFYW9ZUF: Regular Women Light Blue Jeans → score = 2.2765
#  - JEAFCXFZH7H9N87D: Regular Women Grey Jeans → score = 2.2574
#  - JEAFA76SX7HMYMZX: Regular Women Brown Jeans → score = 2.2533
#  - JEAFA76SE5ZGG5ZP: Regular Women Grey Jeans → score = 2.2533
#  - JEAFA76SBGAZ3AQZ: Regular Women Brown Jeans → score = 2.2533
#  - JEAFA76S7ZEVHFUR: Regular Men Brown Jeans → score = 2.2533
#  - JEAEKMF3M8NXSHFZ: Regular Women Brown Jeans → score = 2.2371
#  - JEAFGCAEY4ABXZWN: Regular Women Grey Jeans → score = 2.1989
#  - JEAFFDT2ZKWWPGMT: Regular Women Grey Jeans → score = 2.1989
#  - JEAFFDT2ZAUZMMSF: Regular Women Grey Jeans → score = 2.1989
#  - JEAFFDT2ZA2NRC3X: Regular Men Grey Jeans → score = 2.1989
#  - JEAFFDT2XGGRCZGH: Regular Women Grey Jeans → score = 2.1989
#
# Top 20 (BM25) results for: 'regular fit denim jeans'
#  - JEAEEVEQUPC3MHYK: Regular Women Black Jeans → score = 14.089
#  - JEAE92Z37UYPWPVB: Regular Men Blue Jeans → score = 14.088
#  - JEAEAFZKT8GHSGNA: Regular Women Dark Blue Jeans → score = 13.9101
#  - JEAEAFZKGFYW9ZUF: Regular Women Light Blue Jeans → score = 13.9101
#  - JEAE6GBVY8SQQSUK: Sprin Regular Men Blue Jeans → score = 13.843
#  - JEAE8EWUZJDHNF4D: Sprint Denim Regular Men Dark Blue, Light Blue Jeans  (Pack of 2) → score = 13.7891
#  - JEAE6GBVWBWFBHMJ: Sprin Regular Women Dark Blue Jeans → score = 13.6618
#  - JEAEKMF3M8NXSHFZ: Regular Women Brown Jeans → score = 13.1682
#  - JEAEKMF2V5RGFUBU: Regular Men Grey Jeans → score = 13.0093
#  - JEAFFDT2QPZKFGZU: Regular Men Grey Jeans → score = 11.5133
#  - JEAFFDT2XGGRCZGH: Regular Women Grey Jeans → score = 11.5133
#  - JEAFFDT2ZA2NRC3X: Regular Men Grey Jeans → score = 11.5133
#  - JEAFGCAEY4ABXZWN: Regular Women Grey Jeans → score = 11.5133
#  - JEAFFDT2JEZ25AYV: Regular Women Grey Jeans → score = 11.5133
#  - JEAFF4FCFKRCFGSB: Regular Men Brown Jeans → score = 11.5133
#  - JEAFF4FCZVKQBJMP: Regular Men Brown Jeans → score = 11.5133
#  - JEAFF4FCRBBDNTVN: Regular Men Brown Jeans → score = 11.5133
#  - JEAFF4FCYYXEWU3Y: Regular Women Brown Jeans → score = 11.5133
#  - JEAFF4FCCHUPRY9Z: Regular Men Brown Jeans → score = 11.5133
#  - JEAFF4FCY9XWESCR: Regular Men Brown Jeans → score = 11.5133
#
# Top 20 (CUSTOM1) results for: 'regular fit denim jeans'
#  - JEAE92Z37UYPWPVB: Regular Men Blue Jeans → score = 10.0666 | rating=3.6 | discount=61.0
#  - JEAEEVEQUPC3MHYK: Regular Women Black Jeans → score = 10.0483 | rating=3.4 | discount=50.0
#  - JEAEAFZKT8GHSGNA: Regular Women Dark Blue Jeans → score = 9.9231 | rating=3.4 | discount=50.0
#  - JEAEAFZKGFYW9ZUF: Regular Women Light Blue Jeans → score = 9.9151 | rating=3.2 | discount=50.0
#  - JEAE6GBVY8SQQSUK: Sprin Regular Men Blue Jeans → score = 9.8181 | rating=3.2 | discount=0.0
#  - JEAE8EWUZJDHNF4D: Sprint Denim Regular Men Dark Blue, Light Blue Jeans  (Pack of 2) → score = 9.7944 | rating=3.1 | discount=18.0
#  - JEAE6GBVWBWFBHMJ: Sprin Regular Women Dark Blue Jeans → score = 9.6913 | rating=3.2 | discount=0.0
#  - JEAEKMF3M8NXSHFZ: Regular Women Brown Jeans → score = 9.3857 | rating=4.2 | discount=0.0
#  - JEAEKMF2V5RGFUBU: Regular Men Grey Jeans → score = 9.2585 | rating=3.8 | discount=0.0
#  - JEAFF4FCY9XWESCR: Regular Men Brown Jeans → score = 8.2753 | rating=4.0 | discount=56.0
#  - JEAFF4FCRJ2MRFWZ: Regular Women Brown Jeans → score = 8.2753 | rating=4.0 | discount=56.0
#  - JEAFF4FCZVKQBJMP: Regular Men Brown Jeans → score = 8.2753 | rating=4.0 | discount=56.0
#  - JEAFF4FCCHUPRY9Z: Regular Men Brown Jeans → score = 8.2753 | rating=4.0 | discount=56.0
#  - JEAFF4FCYYXEWU3Y: Regular Women Brown Jeans → score = 8.2753 | rating=4.0 | discount=56.0
#  - JEAFFDT26HFCQMU5: Regular Women Grey Jeans → score = 8.2713 | rating=3.9 | discount=56.0
#  - JEAFFDT2JEZ25AYV: Regular Women Grey Jeans → score = 8.2713 | rating=3.9 | discount=56.0
#  - JEAFFDT2ZKWWPGMT: Regular Women Grey Jeans → score = 8.2713 | rating=3.9 | discount=56.0
#  - JEAFFDT2VYYZMCBD: Regular Men Grey Jeans → score = 8.2713 | rating=3.9 | discount=56.0
#  - JEAFFDT2XGGRCZGH: Regular Women Grey Jeans → score = 8.2713 | rating=3.9 | discount=56.0
#  - JEAFF4FCHNHAXDVY: Regular Men Brown Jeans → score = 8.2693 | rating=4.0 | discount=50.0
#
# Top 20 (CUSTOM2) results for: 'regular fit denim jeans'
#  - JEAFEH2TNJDVHC4D: Regular Men Dark Blue Jeans → score = 4.8599 | rating=3.9 | price=653.0| discount=49.0
#  - JEAFEH2STJYPUEYQ: Regular Men Blue Jeans → score = 4.8073 | rating=4.0 | price=699.0| discount=46.0
#  - JEAFEH2TAH6H5HEV: Regular Men Black Jeans → score = 4.7898 | rating=3.9 | price=699.0| discount=46.0
#  - JEAFEH2SMKHNEGGK: Regular Women Blue Jeans → score = 4.72 | rating=4.0 | price=699.0| discount=46.0
#  - JEAFEH2S6NG6FGDN: Regular Men Blue Jeans → score = 4.6546 | rating=4.0 | price=799.0| discount=38.0
#  - JEAFEH2SZHGRNVJX: Regular Women Blue Jeans → score = 4.6546 | rating=4.0 | price=799.0| discount=38.0
#  - JEAFEH2TGHCEGZZ8: Regular Men Black Jeans → score = 4.6377 | rating=3.9 | price=799.0| discount=38.0
#  - JEAFEH2T6HFUJGUH: Regular Women Black Jeans → score = 4.6377 | rating=3.9 | price=799.0| discount=38.0
#  - JEAFEHYVDGBFZNGV: Regular Women Blue Jeans → score = 4.3503 | rating=2.2 | price=799.0| discount=38.0
#  - JEAFEHYVHUYCCKWW: Regular Women Blue Jeans → score = 4.3503 | rating=2.2 | price=799.0| discount=38.0
#  - JEAFEHYVZHNURZYH: Regular Men Blue Jeans → score = 4.3503 | rating=2.2 | price=799.0| discount=38.0
#  - JEAFF2RPM4STCXFT: Regular Men Light Blue Jeans → score = 4.1348 | rating=4.1 | price=649.0| discount=56.0
#  - JEAFF2RPERZ6BTP9: Regular Women Light Blue Jeans → score = 4.1348 | rating=4.1 | price=649.0| discount=56.0
#  - JEAFF2RPKG2GSASU: Regular Women Light Blue Jeans → score = 4.1348 | rating=4.1 | price=649.0| discount=56.0
#  - JEAFF4FCY9XWESCR: Regular Men Brown Jeans → score = 4.1199 | rating=4.0 | price=649.0| discount=56.0
#  - JEAFF4FCRJ2MRFWZ: Regular Women Brown Jeans → score = 4.1199 | rating=4.0 | price=649.0| discount=56.0
#  - JEAFF4FCZVKQBJMP: Regular Men Brown Jeans → score = 4.1199 | rating=4.0 | price=649.0| discount=56.0
#  - JEAFF4FCCHUPRY9Z: Regular Men Brown Jeans → score = 4.1199 | rating=4.0 | price=649.0| discount=56.0
#  - JEAFF4FCYYXEWU3Y: Regular Women Brown Jeans → score = 4.1199 | rating=4.0 | price=649.0| discount=56.0
#  - JEAFFDT26HFCQMU5: Regular Women Grey Jeans → score = 4.1049 | rating=3.9 | price=649.0| discount=56.0

# %% [markdown]
# # **PART 2**

# %% [markdown]
# # WORD2VEC + COSINE RANKING

# %%
def train_custom_word2vec(corpus_tokens, vector_size=50):
    print("Training custom Word2Vec model...")
    model = Word2Vec(
        sentences=corpus_tokens,
        vector_size=vector_size,
        window=5,
        min_count=1,
        workers=4
    )
    return model.wv

def tokens_to_vector(tokens, model):
    """Converteix una llista de tokens en un vector mitjà basat en Word2Vec."""
    vectors = [model[word] for word in tokens if word in model]
    if not vectors:
        return np.zeros(model.vector_size)
    return np.mean(vectors, axis=0)

def word2vec_ranking_topk(model, doc_vectors, products_info, queries, top_k=20):
    """
    Retorna els top-k documents per a cada query usant Word2Vec + cosine similarity.

    Args:
        model: model preentrenat (Word2Vec/Glove).
        doc_vectors (list of tuples): [(pid, vector), ...] vectors dels documents.
        products_info (dict): informació completa dels productes per pid.
        queries (dict): diccionari de queries {qid: "query text"}.
        top_k (int): nombre màxim de documents a retornar.

    Returns:
        dict: {qid: {"query": query_text, "results": [(product_info, score), ...]}}
    """
    # Extract only the vectors for more efficient computations
    vectors_only = np.array([vec for pid, vec in doc_vectors])

    results = {}

    for qid, query_text in queries.items():
        # Preprocess query and obtain its vector
        q_tokens = build_terms(query_text)
        q_vec = tokens_to_vector(q_tokens, model)

        # Comute cosinus similarity with all documents
        sims = cosine_similarity([q_vec], vectors_only)[0]

        # Top-k documents
        top_indices = sims.argsort()[::-1][:top_k]

        ranked_docs = []
        for idx in top_indices:
            pid, _ = doc_vectors[idx]
            info = products_info[pid]
            ranked_docs.append((info, float(sims[idx])))

        results[qid] = {
            "query": query_text,
            "results": ranked_docs
        }

    return results

# %%
corpus_tokens = []
for doc in lines:
    text = f"{doc.get('title', '')} {doc.get('description', '')}"
    corpus_tokens.append(build_terms(text))

# Train custom Word2Vec
model = train_custom_word2vec(corpus_tokens)
# Out:
# Training custom Word2Vec model...

# %%
# Compute vectors
print("Converting documents to vectors...")
doc_vectors = []  # list of tuples (pid, vector)
for doc in lines:
    pid = doc.get("pid", "")
    title = doc.get("title", "")
    description = doc.get("description", "")
    text = f"{title} {description}"
    terms = build_terms(text)
    vec = tokens_to_vector(terms, model)
    doc_vectors.append((pid, vec))
# Out:
# Converting documents to vectors...

# %%
rankings = word2vec_ranking_topk(model=model,doc_vectors=doc_vectors,products_info=products_info,queries=queries,top_k=20)

for qid, data in rankings.items():
    print(f"\nTop {20} results for Query {qid}: '{data['query']}'")
    for i, (info, score) in enumerate(data['results'], 1):
        print(f"{i:2d}. {info['pid']}: {info['title']} → score = {score:.4f}")
# Out:
# Top 20 results for Query 1: 'men cotton blend grey t shirt'
#  1. TSHFE4JPXV56KKB2: Solid Women Polo Neck Black T-Shirt → score = 0.9032
#  2. TSHFE4JRQ8HHCYYM: Solid Men Polo Neck Blue T-Shirt → score = 0.8994
#  3. TSHFE4JQZ2TJBGMZ: Solid Men Polo Neck White T-Shirt → score = 0.8956
#  4. TSHFE4JPXMUVVMJR: Solid Women Polo Neck Blue T-Shirt → score = 0.8939
#  5. KTAFVHTGDWZG3NPC: Men Solid Cotton Blend Pathani Kurta  (Yellow) → score = 0.8765
#  6. KTAFVHTGUGGGZCZV: Men Solid Cotton Blend Pathani Kurta  (Yellow) → score = 0.8765
#  7. KTAFAKGUKA2SXSEQ: Men Solid Cotton Blend Pathani Kurta  (Blue) → score = 0.8738
#  8. KTAFVHTGUUBZGYFU: Women Solid Cotton Blend Pathani Kurta  (Blue) → score = 0.8735
#  9. KTAFVA6R7AQPFM3E: Women Solid Cotton Blend Asymmetric Kurta  (Orange) → score = 0.8623
# 10. KTAFVHTGZUPYKGZA: Men Solid Cotton Blend Pathani Kurta  (Orange) → score = 0.8570
# 11. KTAFWKJYFQBAAAQC: Women Polka Print Cotton Blend A-line Kurta  (Green) → score = 0.8565
# 12. TROFN8YNBWZKQXST: Tapered Men Green Cotton Blend Trousers → score = 0.8550
# 13. KTAFVHTGRA4RKDCT: Men Solid Cotton Blend Pathani Kurta  (Pink) → score = 0.8538
# 14. KTAFWKJYCKFHAHXZ: Men Polka Print Cotton Blend A-line Kurta  (Red) → score = 0.8529
# 15. KTAFWQ5GRHK4MRBK: Women Solid Cotton Jute Blend Pathani Kurta  (Maroon) → score = 0.8522
# 16. KTAFWQ5GXYGYV3AF: Men Solid Cotton Jute Blend Pathani Kurta  (Maroon) → score = 0.8520
# 17. KTAFH7NBG8PEX5GP: Women Solid Cotton Blend Straight Kurta  (Maroon, Yellow) → score = 0.8488
# 18. TSHER6FBWFYYR5GG: Solid Men Round Neck Multicolor T-Shirt  (Pack of 3) → score = 0.8445
# 19. KTAFVHTGWSRVHXZ2: Women Solid Cotton Blend Pathani Kurta  (Light Blue) → score = 0.8443
# 20. TSHEM8ZVNGGUC7JY: Solid Men Polo Neck Black T-Shirt → score = 0.8437
#
# Top 20 results for Query 2: 'light blue jeans for men slim fit'
#  1. JEAFXUE4HV4MMZ2Z: Tapered Fit Men Light Blue Jeans → score = 0.9759
#  2. JEAFXUDZ6BXY9BZ2: Tapered Fit Men Light Blue Jeans → score = 0.9759
#  3. JEAFXUECDBWZ5CVZ: Tapered Fit Men Light Blue Jeans → score = 0.9759
#  4. JEAFQF6JYNMVZQN7: Tapered Fit Men Light Blue Jeans → score = 0.9759
#  5. JEAFQF6K9GPHQTZX: Tapered Fit Women Light Blue Jeans → score = 0.9755
#  6. JEAFWBJKYTRBZEZD: Tapered Fit Women Light Blue Jeans → score = 0.9755
#  7. JEAFXUECQ6BWC3WY: Tapered Fit Women Light Blue Jeans → score = 0.9755
#  8. JEAFWBJKGBFMSNBE: Tapered Fit Women Light Blue Jeans → score = 0.9755
#  9. JEAFVXHKTSH3GXUG: Slim Men Light Blue Jeans → score = 0.9741
# 10. JEAENP3UUGESZVH9: Slim Men Light Blue Jeans → score = 0.9741
# 11. JEAF8HYNFRPCRJRM: Slim Women Light Blue Jeans → score = 0.9734
# 12. JEAFSKYHJCEYJZCB: Slim Women Light Blue Jeans → score = 0.9734
# 13. JEAFW4DUEGRPEYDR: Slim Women Light Blue Jeans → score = 0.9669
# 14. JEAFUZXSHCZNHQE4: Tapered Fit Men Light Blue Jeans → score = 0.9588
# 15. JEAFSKYHHDQ2SDZQ: Tapered Fit Men Light Blue Jeans → score = 0.9555
# 16. JEAFUZXT2J3VV2RR: Tapered Fit Men Light Blue Jeans → score = 0.9514
# 17. JEAFUZXSYF7FWBQM: Skinny Women Light Blue Jeans → score = 0.9485
# 18. JEAFW4DUZ6KB5DGV: Super Skinny Women Light Blue Jeans → score = 0.9391
# 19. JEAF8PNBKAAHCUGG: Regular Women Light Blue Jeans → score = 0.9391
# 20. JEAFJM2P2FQQJF3C: Slim Men Dark Blue Jeans → score = 0.9388
#
# Top 20 results for Query 3: 'women casual wear cotton shirt'
#  1. SHTFPGVCBTG694MD: Men Regular Fit Printed Casual Shirt → score = 0.9042
#  2. SHTFPGVCBX6H4PTG: Men Regular Fit Printed Casual Shirt → score = 0.9042
#  3. SHTFPGVCR3PN7ZME: Women Regular Fit Printed Casual Shirt → score = 0.9011
#  4. TSHES4ECH68XZQRH: Solid Men Mandarin Collar White T-Shirt → score = 0.8943
#  5. TSHES4E2MYTF3HVB: Solid Men Mandarin Collar Black T-Shirt → score = 0.8926
#  6. TSHES4E2XHAN2CMJ: Solid Men Mandarin Collar Red T-Shirt → score = 0.8923
#  7. TSHES4E2GBEZEAPG: Solid Women Polo Neck Blue T-Shirt → score = 0.8919
#  8. TSHEXH59UKJ7SUPR: Solid Men V-neck Black T-Shirt → score = 0.8918
#  9. TSHEXH59FAXKYQUN: Solid Women V-neck Red T-Shirt → score = 0.8888
# 10. TSHES4EB5CEYYNRN: Solid Women Mandarin Collar Blue T-Shirt → score = 0.8884
# 11. TSHEXH59KYGCHCMU: Military Camouflage Men Round Neck Multicolor T-Shirt → score = 0.8883
# 12. SHTFSPTZCH3XHWVB: Women Slim Fit Solid Casual Shirt → score = 0.8882
# 13. TSHFWBWEXX3N9FHZ: Solid Women Round Neck Blue, Maroon T-Shirt  (Pack of 3) → score = 0.8870
# 14. TSHFWBWESMCTBUKC: Solid Men Round Neck Dark Blue T-Shirt  (Pack of 3) → score = 0.8866
# 15. TSHEXH59JKHGZYTM: Solid Women Round Neck White, Blue T-Shirt → score = 0.8856
# 16. SHTFTQHVDJNYZBJG: Women Regular Fit Printed Double Collar Collar Party Shirt → score = 0.8855
# 17. TSHEXH594ZTCQ6AZ: Solid Women Round Neck Black T-Shirt → score = 0.8853
# 18. TSHEXH59VWFSPVZ7: Military Camouflage Women V-neck Multicolor T-Shirt → score = 0.8853
# 19. TSHFWBWEV3J285KG: Solid Women Round Neck Blue T-Shirt  (Pack of 3) → score = 0.8853
# 20. TSHEGHG2YWG7TZJQ: Solid Men Polo Neck Black T-Shirt → score = 0.8852
#
# Top 20 results for Query 4: 'printed navy top for women'
#  1. TGTFWF6QJXFPZP77: Printed Men Orange Tights → score = 0.9016
#  2. TGTFWF6QEMB3KQ7C: Printed Men Orange Tights → score = 0.9016
#  3. TGTFWF6ZCGA72A4Q: Printed Women Orange Tights → score = 0.8976
#  4. TGTFWF6QWSHS5RGH: Printed Women Orange Tights → score = 0.8976
#  5. TSHFMF8GPKMJACF8: Printed Men Round Neck Dark Blue T-Shirt → score = 0.8881
#  6. TSHFZ3JDBYXZFURF: Solid Women Round Neck Black T-Shirt → score = 0.8876
#  7. TSHFMF8HZJQ23N5S: Printed Men Round Neck Dark Blue T-Shirt → score = 0.8854
#  8. TSHFGZKNU2ZXTWB9: Printed Men Round Neck Dark Blue T-Shirt → score = 0.8835
#  9. TSHFZJNZT2BFUKBX: Printed Men Hooded Neck Dark Blue T-Shirt → score = 0.8830
# 10. TSHFTKC3AQVMRN7D: Printed Men Henley Neck Dark Blue T-Shirt → score = 0.8822
# 11. TSHFGZKQ9DHBZXMA: Printed Women Round Neck Dark Blue T-Shirt → score = 0.8815
# 12. TSHFKNY6G5UMPYFE: Printed Women s Dark Blue T-Shirt → score = 0.8803
# 13. TSHFNZGFATG8S4RV: Printed Women Henley Neck Dark Blue T-Shirt → score = 0.8803
# 14. TSHFKH7XJRJYMRPD: Printed Men V Neck Dark Blue T-Shirt → score = 0.8785
# 15. BDAFUBD2EJHFCRNC: Men Printed Bandana → score = 0.8782
# 16. TSHFHSNP4PX6KUWG: Striped Women Polo Neck Dark Blue T-Shirt → score = 0.8779
# 17. TSHF3HMBZWAZPS45: Printed Women V-neck Dark Blue T-Shirt → score = 0.8766
# 18. TSHFP9J5ECNUXHEJ: Printed Women V Neck Dark Blue T-Shirt → score = 0.8766
# 19. TSHFFXYJ4BYKXCZ5: Solid Men Hooded Neck Dark Blue T-Shirt → score = 0.8748
# 20. TSHFE4JQHUJTHGFM: Striped Women Polo Neck Blue T-Shirt → score = 0.8719
#
# Top 20 results for Query 5: 'regular fit denim jeans'
#  1. JEAEKMF3M8NXSHFZ: Regular Women Brown Jeans → score = 0.8893
#  2. JEAFUPSWVCTKXMHF: Tapered Fit Men Blue Jeans → score = 0.8888
#  3. JEAFS2JVMPZYGKZA: Slim Women Black Jeans → score = 0.8798
#  4. JEAFUZXS4AGG5HAQ: Skinny Women Blue Jeans → score = 0.8779
#  5. JEAFUZXSYS6GHGYH: Skinny Women Blue Jeans → score = 0.8779
#  6. JEAFUZXTFZGGMYFB: Skinny Women Blue Jeans → score = 0.8779
#  7. JEAFS2JZHCWVVTQY: Slim Women Blue Jeans → score = 0.8778
#  8. JEAFUZXTDFARUHFR: Skinny Men Blue Jeans → score = 0.8751
#  9. JEAFXUHFDUQGBHEB: Tapered Fit Women Black Jeans → score = 0.8743
# 10. JEAFWBJKAY9UHW8T: Skinny Women Blue Jeans → score = 0.8727
# 11. JEAFSKYHHWSGEDHP: Tapered Fit Men White Jeans → score = 0.8726
# 12. JEAFXUHUQHXQQDYJ: Tapered Fit Women Blue Jeans → score = 0.8677
# 13. SHTEWNDGGSFSGQZU: Women Slim Fit Solid Spread Collar Casual Shirt → score = 0.8631
# 14. JEAFSKYH539HTZB8: Tapered Fit Men Blue Jeans → score = 0.8628
# 15. SHTEWNDGDFQYBXGY: Men Slim Fit Solid Spread Collar Casual Shirt → score = 0.8624
# 16. SHTEWNDGVV49Z54K: Men Slim Fit Solid Spread Collar Casual Shirt → score = 0.8624
# 17. JEAFUZXSBBCAY7V6: Skinny Women Grey Jeans → score = 0.8613
# 18. JEAFUZXTHR9UUXCG: Skinny Men Blue Jeans → score = 0.8602
# 19. JEAFSKYHRVZSABPR: Slim Men Blue Jeans → score = 0.8599
# 20. JEAFSKYHTE76YWH7: Slim Men Blue Jeans → score = 0.8599

# %% [markdown]
# # EVALUATION - Analysis and Comparison of Approaches

# %% [markdown]
# Precision@k

# %%
def precision_at_k(doc_score, y_score, k=10):
    """
    Parameters
    ----------
    doc_score: Ground truth (true relevance labels).
    y_score: Predicted scores.
    k : number of doc to consider.

    Returns
    -------
    precision @k : float

    """
    order = np.argsort(y_score)[::-1]  # Bonus point: How to improve the effitiency of this part?
    #doc_score = np.take(doc_score, order[:k])
    doc_score = doc_score[order[:k]]
    relevant = sum(doc_score == 1)
    return float(relevant) / k

# %% [markdown]
# Recall@k

# %%
def recall_at_k(doc_score, y_score, k=10):
    """
    Parameters
    ----------
    doc_score : Ground truth (true relevance labels, binary: 1=relevant, 0=non-relevant)
    y_score   : Predicted scores
    k         : Number of top documents to consider

    Returns
    -------
    recall@k : float
    """
    order = np.argsort(y_score)[::-1]  # Sort documents by predicted score (descending)
    doc_score_k = doc_score[order[:k]]  # Take top-k documents
    relevant_retrieved = sum(doc_score_k == 1)
    total_relevant = sum(doc_score == 1)

    if total_relevant == 0:
        return 0.0  # Avoid division by zero

    return float(relevant_retrieved) / total_relevant

# %% [markdown]
# F1@k

# %%
def f1_at_k(doc_score, y_score, k=10):
    """
    Parameters
    ----------
    doc_score : Ground truth (true relevance labels, binary: 1=relevant, 0=non-relevant)
    y_score   : Predicted scores
    k         : Number of top documents to consider

    Returns
    -------
    F1@k : float
    """
    order = np.argsort(y_score)[::-1]  # sort by predicted score (descending)
    doc_score_k = doc_score[order[:k]]

    relevant_retrieved = sum(doc_score_k == 1)
    total_relevant = sum(doc_score == 1)

    if total_relevant == 0:
        return 0.0  # avoid division by zero

    precision = relevant_retrieved / k
    recall = relevant_retrieved / total_relevant

    if (precision + recall) == 0:
        return 0.0

    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

# %%
# Load validation file with the 4 relevance types
validation_df = pd.read_csv(our_validation_path)

# Columns in the CSV used as different relevance definitions
relevance_strategies = ["Exact coincidence", "All - 1", ">= 70%", "product types"]

# Ranking methods implemented in your code
ranking_methods = ["tf-idf", "bm25", "custom1", "custom2"]

query_ids = validation_df["query_id"].unique()

results = []
k = 10  # or 20 if you prefer; must be <= number of docs per query

for qid in query_ids:
    # Skip if this query_id is not in your queries dict
    if qid not in queries:
        continue

    query_text = queries[qid]
    q_data = validation_df[validation_df["query_id"] == qid].copy()

    # NOTE: your validation CSV must have a 'pid' column listing candidate products
    all_pids = q_data["pid"].values

    for method in ranking_methods:
        # Get ranking from your search function
        ranked_docs, doc_scores = search_products(
            query_text, index, idf, tf, products_info, ranking_method=method
        )

        # Build a score vector aligned with all_pids
        # Higher score = better rank (top result has largest value)
        y_score = np.zeros(len(all_pids), dtype=float)
        for rank, pid in enumerate(ranked_docs):
            if pid in all_pids:
                idx = np.where(all_pids == pid)[0][0]
                y_score[idx] = len(ranked_docs) - rank  # invert rank

        # Add tiny random noise to break ties
        y_score = y_score + np.random.rand(len(y_score)) * 0.01

        # Evaluate for each relevance strategy/column
        for strategy in relevance_strategies:
            if strategy not in q_data.columns:
                continue

            # Binary ground truth for this strategy
            doc_score = q_data[strategy].astype(int).values

            results.append({
                "Query": f"Query {qid}",
                "Method": method.upper(),
                "Relevance Strategy": strategy,
                f"Precision@{k}": round(precision_at_k(doc_score, y_score, k), 3),
                f"Recall@{k}": round(recall_at_k(doc_score, y_score, k), 3),
                f"F1@{k}": round(f1_at_k(doc_score, y_score, k), 3),
            })

# Turn into DataFrame and display
results_df = pd.DataFrame(results)
display(results_df)

# Optional: average per (Method, Relevance Strategy)
avg_results = (
    results_df
    .groupby(["Method", "Relevance Strategy"])[[f"Precision@{k}", f"Recall@{k}", f"F1@{k}"]]
    .mean()
    .round(3)
)
display(avg_results)
# Out:
#       Query   Method Relevance Strategy  Precision@10  Recall@10  F1@10
# 0   Query 1   TF-IDF  Exact coincidence           0.0      0.000  0.000
# 1   Query 1   TF-IDF            All - 1           0.0      0.000  0.000
# 2   Query 1   TF-IDF             >= 70%           1.0      0.556  0.714
# 3   Query 1   TF-IDF      product types           0.9      0.692  0.783
# 4   Query 1     BM25  Exact coincidence           0.0      0.000  0.000
# ..      ...      ...                ...           ...        ...    ...
# 75  Query 5  CUSTOM1      product types           1.0      0.400  0.571
# 76  Query 5  CUSTOM2  Exact coincidence           0.0      0.000  0.000
# 77  Query 5  CUSTOM2            All - 1           0.0      0.000  0.000
# 78  Query 5  CUSTOM2             >= 70%           0.0      0.000  0.000
# 79  Query 5  CUSTOM2      product types           1.0      0.400  0.571
#
# [80 rows x 6 columns]
#                             Precision@10  Recall@10  F1@10
# Method  Relevance Strategy
# BM25    >= 70%                      0.40      0.511  0.369
#         All - 1                     0.20      0.400  0.226
#         Exact coincidence           0.14      0.400  0.200
#         product types               0.80      0.683  0.649
# CUSTOM1 >= 70%                      0.40      0.511  0.369
#         All - 1                     0.20      0.400  0.226
#         Exact coincidence           0.14      0.400  0.200
#         product types               0.80      0.683  0.649
# CUSTOM2 >= 70%                      0.38      0.311  0.332
#         All - 1                     0.20      0.300  0.223
#         Exact coincidence           0.04      0.200  0.067
#         product types               0.76      0.652  0.615
# TF-IDF  >= 70%                      0.40      0.511  0.369
#         All - 1                     0.20      0.400  0.226
#         Exact coincidence           0.14      0.400  0.200
#         product types               0.82      0.698  0.667

# %%
# === Evaluation of Word2Vec ranking against the same relevance strategies ===

w2v_results = []
k = 10  # use same k as in the previous block

for qid in query_ids:
    # We need both the query text and its Word2Vec results
    if qid not in queries or qid not in rankings:
        continue

    q_data = validation_df[validation_df["query_id"] == qid].copy()
    if "pid" not in q_data.columns:
        continue

    all_pids = q_data["pid"].values

    # Extract ranked pids from Word2Vec results:
    # rankings[qid]["results"] is a list of (info_dict, score_float)
    ranked = rankings[qid]["results"]
    ranked_pids = [info["pid"] for info, _ in ranked]

    # Build score vector aligned with all_pids
    y_score = np.zeros(len(all_pids), dtype=float)
    for rank, pid in enumerate(ranked_pids):
        if pid in all_pids:
            idx = np.where(all_pids == pid)[0][0]
            y_score[idx] = len(ranked_pids) - rank  # invert rank so top has largest score

    # Add tiny random noise to break ties
    y_score = y_score + np.random.rand(len(y_score)) * 0.01

    # Evaluate for each relevance strategy / column
    for strategy in relevance_strategies:
        if strategy not in q_data.columns:
            continue

        # Binary ground truth for this strategy
        doc_score = q_data[strategy].astype(int).values

        w2v_results.append({
            "Query": f"Query {qid}",
            "Method": "WORD2VEC",
            "Relevance Strategy": strategy,
            f"Precision@{k}": round(precision_at_k(doc_score, y_score, k), 3),
            f"Recall@{k}": round(recall_at_k(doc_score, y_score, k), 3),
            f"F1@{k}": round(f1_at_k(doc_score, y_score, k), 3),
        })

w2v_df = pd.DataFrame(w2v_results)
display(w2v_df)

# Optional: average metrics for Word2Vec per relevance strategy
w2v_avg = (
    w2v_df
    .groupby("Relevance Strategy")[[f"Precision@{k}", f"Recall@{k}", f"F1@{k}"]]
    .mean()
    .round(3)
)
display(w2v_avg)
# Out:
#       Query    Method Relevance Strategy  Precision@10  Recall@10  F1@10
# 0   Query 1  WORD2VEC  Exact coincidence           0.0      0.000  0.000
# 1   Query 1  WORD2VEC            All - 1           0.1      0.500  0.167
# 2   Query 1  WORD2VEC             >= 70%           1.0      0.556  0.714
# 3   Query 1  WORD2VEC      product types           0.7      0.538  0.609
# 4   Query 2  WORD2VEC  Exact coincidence           0.2      1.000  0.333
# 5   Query 2  WORD2VEC            All - 1           0.9      1.000  0.947
# 6   Query 2  WORD2VEC             >= 70%           0.9      1.000  0.947
# 7   Query 2  WORD2VEC      product types           0.9      1.000  0.947
# 8   Query 3  WORD2VEC  Exact coincidence           0.0      0.000  0.000
# 9   Query 3  WORD2VEC            All - 1           0.0      0.000  0.000
# 10  Query 3  WORD2VEC             >= 70%           0.0      0.000  0.000
# 11  Query 3  WORD2VEC      product types           1.0      0.400  0.571
# 12  Query 4  WORD2VEC  Exact coincidence           0.0      0.000  0.000
# 13  Query 4  WORD2VEC            All - 1           0.0      0.000  0.000
# 14  Query 4  WORD2VEC             >= 70%           0.0      0.000  0.000
# 15  Query 4  WORD2VEC      product types           0.3      1.000  0.462
# 16  Query 5  WORD2VEC  Exact coincidence           0.1      0.200  0.133
# 17  Query 5  WORD2VEC            All - 1           0.0      0.000  0.000
# 18  Query 5  WORD2VEC             >= 70%           0.0      0.000  0.000
# 19  Query 5  WORD2VEC      product types           1.0      0.400  0.571
#                     Precision@10  Recall@10  F1@10
# Relevance Strategy
# >= 70%                      0.38      0.311  0.332
# All - 1                     0.20      0.300  0.223
# Exact coincidence           0.06      0.240  0.093
# product types               0.78      0.668  0.632

# %%
# Combine all evaluations (text-based methods + Word2Vec)
all_eval_df = pd.concat([results_df, w2v_df], ignore_index=True)

overall_avg = (
    all_eval_df
    .groupby(["Method", "Relevance Strategy"])[[f"Precision@{k}", f"Recall@{k}", f"F1@{k}"]]
    .mean()
    .round(3)
)

display(overall_avg.sort_values(["Relevance Strategy", f"F1@{k}"], ascending=[True, False]))
# Out:
#                              Precision@10  Recall@10  F1@10
# Method   Relevance Strategy
# BM25     >= 70%                      0.40      0.511  0.369
# CUSTOM1  >= 70%                      0.40      0.511  0.369
# TF-IDF   >= 70%                      0.40      0.511  0.369
# CUSTOM2  >= 70%                      0.38      0.311  0.332
# WORD2VEC >= 70%                      0.38      0.311  0.332
# BM25     All - 1                     0.20      0.400  0.226
# CUSTOM1  All - 1                     0.20      0.400  0.226
# TF-IDF   All - 1                     0.20      0.400  0.226
# CUSTOM2  All - 1                     0.20      0.300  0.223
# WORD2VEC All - 1                     0.20      0.300  0.223
# BM25     Exact coincidence           0.14      0.400  0.200
# CUSTOM1  Exact coincidence           0.14      0.400  0.200
# TF-IDF   Exact coincidence           0.14      0.400  0.200
# WORD2VEC Exact coincidence           0.06      0.240  0.093
# CUSTOM2  Exact coincidence           0.04      0.200  0.067
# TF-IDF   product types               0.82      0.698  0.667
# BM25     product types               0.80      0.683  0.649
# CUSTOM1  product types               0.80      0.683  0.649
# WORD2VEC product types               0.78      0.668  0.632
# CUSTOM2  product types               0.76      0.652  0.615
